# %%
import os
import csv

# Definisci le estensioni dei file che consideriamo immagini e video
image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff'}
video_extensions = {'.mp4', '.mov', '.avi', '.mkv', '.flv', '.wmv'}

def get_files_in_directory(directory, files):
    """
    Funzione per ottenere tutti i file immagine e video in una directory
    """
    for root, _, filenames in os.walk(directory):
        for filename in filenames:
            if filename.lower().endswith(tuple(image_extensions)) or filename.lower().endswith(tuple(video_extensions)):
                files.append(os.path.join(root, filename))
    return files

def write_files_to_csv(files, output_csv):
    """
    Funzione per scrivere i file in un file CSV
    """
    with open(output_csv, 'w', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        # Scrivi l'intestazione (opzionale)
        csvwriter.writerow(['File Path'])
        
        # Scrivi ogni file in una riga del CSV
        for file in files:
            csvwriter.writerow([file])

# %%
files = []
output_csv = 'Contenuti MultiMediali.csv'

for i in os.listdir(os.getcwd()):
    if i not in ['Prompts.txt', 'Rename.ipynb','Save_csv.ipynb']:
        # Imposta la directory di input e il percorso del file CSV di output
        input_directory = i

        # Ottieni tutti i file nella directory
        files = get_files_in_directory(input_directory, files)

# Scrivi i file nel CSV
write_files_to_csv(files, output_csv)

print(f'Tutti i file sono stati scritti nel file {output_csv}')
# Out:
# Tutti i file sono stati scritti nel file Contenuti MultiMediali.csv
